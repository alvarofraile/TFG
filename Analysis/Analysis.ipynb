# %% [markdown]
# # ANALYSIS

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Training

# %%
training_data = pd.read_csv("./training3_UnitAgent.csv")
training_data
# Out:
#         Wall time    Step        Value
# 0    1.719649e+09    1000   -91.044777
# 1    1.719649e+09    2000   -95.238098
# 2    1.719649e+09    3000   -95.161293
# 3    1.719649e+09    4000   -94.736839
# 4    1.719649e+09    5000   -94.000000
# ..            ...     ...          ...
# 225  1.719750e+09  246000  7079.545410
# 226  1.719750e+09  247000  8032.652832
# 227  1.719750e+09  248000  7509.803711
# 228  1.719750e+09  249000  8808.333008
# 229  1.719750e+09  250000  5271.428711
#
# [230 rows x 3 columns]

# %%
sns.lineplot(training_data, x = "Step", y = "Value")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Value'>

# %% [markdown]
# ## Rendimiento

# %%
# [Wins, Draws, Losses]
resultsTraining = [403, 6, 91]

keys = ['Win', 'Draw', 'Loss'] 
  
palette = ["#00B000", "#808080", "#F00000"]
  
# plotting data on chart 
plt.pie(resultsTraining, labels=keys, colors=sns.color_palette(palette, 3), autopct='%.0f%%') 
  
# displaying chart 
plt.show()

# %%
# [Wins, Draws, Losses]
# 400 games
resultsTesting = [261, 70, 169]

keys = ['Win', 'Draw', 'Loss'] 
  
palette = ["#00B000", "#808080", "#F00000"]
  
# plotting data on chart 
plt.pie(resultsTesting, labels=keys, colors=sns.color_palette(palette, 3), autopct='%.0f%%') 
  
# displaying chart 
plt.show()

# %% [markdown]
# ## Comportamiento

# %%
# [Shoot, MoveOffense, MoveDefense, Melee, Heal]
actionsTraining = [16880, 1141, 25804, 20, 8177]


sns.barplot(x = ["Shoot\n(16880)", "MoveOffense\n(1141)", "MoveDefense\n(25804)", "Melee\n(20)", "Heal\n(8177)"], y = actionsTraining, palette=sns.color_palette("cool"))
# Out:
# <AxesSubplot:>

# %%
# [Shoot, MoveOffense, MoveDefense, Melee, Heal]
actionsTesting = [13056, 901, 23652, 23, 7679]


sns.barplot(x = ["Shoot", "MoveOffense", "MoveDefense", "Melee", "Heal"], y = actionsTesting, palette=sns.color_palette("cool"))
# Out:
# <AxesSubplot:>
